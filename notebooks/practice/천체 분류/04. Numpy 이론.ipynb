# %% [markdown]
# # 선형회귀 데모
#
# ## 라이브러리 및 임포트 설정

# %%
#!pip install tqdm.notebook

# %matplotlib inline

from matplotlib import pyplot as plt
from matplotlib import rcParams
import numpy as np
import pandas as pd
from pathlib import Path
import seaborn as sns
from tqdm.notebook import tqdm
import warnings

# %%
rcParams['figure.figsize'] = (16, 8)
plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', 100)
pd.set_option('display.precision', 4)
warnings.simplefilter('ignore')

# %% [markdown]
# ## 학습 데이터 로드

# %%
data_dir = Path(r'C:\Users\789\Desktop\github_local\Machine Learning\machine-learning-projects\data\astronomical-object')
trn_file = data_dir / 'train.csv'
seed = 42

# %%
trn = pd.read_csv(trn_file, index_col = 0)
print(trn.shape)
trn.head()
# Out:
# (199991, 22)
#               type  fiberID  psfMag_u  psfMag_g  psfMag_r  psfMag_i  psfMag_z  \
# id
# 0              QSO      601   23.1982   21.4320   21.3141   21.1766   21.1714
# 1              QSO      788   21.4314   20.7081   20.6789   20.7034   20.4732
# 2              QSO      427   17.8515   16.7279   16.6797   16.6946   16.6418
# 3              QSO      864   20.7899   20.0404   19.9269   19.8438   19.4633
# 4   STAR_RED_DWARF      612   26.4550   23.0588   21.4714   19.5050   18.3891
#
#     fiberMag_u  fiberMag_g  fiberMag_r  fiberMag_i  fiberMag_z  petroMag_u  \
# id
# 0      22.5813     21.6445     21.6576     21.3877     21.5728     22.5043
# 1      21.8688     21.0298     20.9671     20.9377     21.0636     21.3607
# 2      18.1719     17.0331     16.9997     17.0960     17.0764     17.8673
# 3      21.0390     20.3172     20.2179     20.0739     19.7945     20.4339
# 4      25.7006     23.6291     21.7428     19.8617     18.8104     25.8592
#
#     petroMag_g  petroMag_r  petroMag_i  petroMag_z  modelMag_u  modelMag_g  \
# id
# 0      21.4316     21.4783     21.1454     20.4224     22.7492     21.4655
# 1      20.7790     20.8897     20.6398     20.6467     21.4930     20.7585
# 2      16.7388     16.6889     16.7442     16.8080     17.8181     16.6974
# 3      19.9937     19.9855     19.7509     19.4551     20.7707     20.0017
# 4      22.4269     21.6736     19.6100     18.3761     24.8771     23.1480
#
#     modelMag_r  modelMag_i  modelMag_z
# id
# 0      21.3642     21.0206     21.1473
# 1      20.7539     20.6934     20.5123
# 2      16.6412     16.6602     16.6889
# 3      19.8898     19.7581     19.5529
# 4      21.4753     19.4873     18.3757

# %%
sns.pairplot(data = trn.sample(n=1000), vars = ['fiberMag_r','fiberMag_i'], hue = 'type', size = 5)

# %% [markdown]
# Let's do simple linear regression with fiberMag_r and fiberMag_i

# %%
X = trn[['fiberMag_r']].values
y = trn['fiberMag_i'].values
print(X.shape, y.shape)
# Out:
# (199991, 1) (199991,)

# %% [markdown]
# ### RMSE loss function definition

# %%
rmse = lambda y, p : np.sqrt(np.mean((y-p)**2))

# %% [markdown]
# 넘파이를 이용한 선형회귀. Hardcoding

# %%
alpha = .0001
b = .1
w = .1
epoch = 10

# %%
x = X.flatten() # 1차원으로 차원 맞춰주기
x = (x - np.mean(x)) / np.std(x) # 입력값 정규화
print(x.shape)
# Out:
# (199991,)

# %%
rmses = []
for i in tqdm(range(epoch)):
  for x_i, y_i in zip(x,y):
    p_i = x_i * w + b
    w = w + alpha * (y_i - p_i) * x_i
    b = b + alpha * (y_i - p_i)
  rmses.append(rmse(y, p_i))
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
w, b
# Out:
# (np.float64(308.846588201261), np.float64(18.285304966021535))

# %%
rmses
# Out:
# [np.float64(122.49304606702593),
#  np.float64(122.49758023966241),
#  np.float64(122.49768856008242),
#  np.float64(122.49769112297729),
#  np.float64(122.49769118360237),
#  np.float64(122.49769118503647),
#  np.float64(122.49769118507037),
#  np.float64(122.49769118507119),
#  np.float64(122.49769118507122),
#  np.float64(122.49769118507122)]

# %%
plt.plot(rmses)

# %%
plt.figure(figsize=(8, 8))
plt.scatter(X, y, alpha=.1)
plt.plot(X, b + w * x, color='darkorange', linewidth=.5)
plt.xlim(0, 40)
plt.ylim(0, 40)
plt.xlabel('u')
plt.ylabel('dered_u')
# Out:
# Text(0, 0.5, 'dered_u')

# %% [markdown]
# ### scikit-learn을 이용한 선형회귀

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X,y)
p = lr.predict(X)

rmse(y, p)
# Out:
# np.float64(106.5206796248524)

# %%
lr.coef_, lr.intercept_
# Out:
# (array([0.66906483]), np.float64(5.381121724754749))

# %%
plt.figure(figsize=(8,8))
plt.scatter(X,y,alpha = .1)
plt.plot(X,p,color='darkorange', linewidth=.5)
plt.xlim(0,40)
plt.ylim(0, 40)
# Out:
# (0.0, 40.0)

# %% [markdown]
# scikit-learn을 이용한 로지스틱 회귀

# %%
X = trn.drop('type', axis = 1)
y = trn['type'].values

print(X.shape, y.shape)
# Out:
# (199991, 21) (199991,)

# %%
np.unique(y) # y의 고유값들 반환
# Out:
# array(['GALAXY', 'QSO', 'REDDEN_STD', 'ROSAT_D', 'SERENDIPITY_BLUE',
#        'SERENDIPITY_DISTANT', 'SERENDIPITY_FIRST', 'SERENDIPITY_MANUAL',
#        'SERENDIPITY_RED', 'SKY', 'SPECTROPHOTO_STD', 'STAR_BHB',
#        'STAR_BROWN_DWARF', 'STAR_CARBON', 'STAR_CATY_VAR', 'STAR_PN',
#        'STAR_RED_DWARF', 'STAR_SUB_DWARF', 'STAR_WHITE_DWARF'],
#       dtype=object)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, roc_auc_score

lr = LogisticRegression()
lr.fit(X,y)
p = lr.predict_proba(X)

# %% [markdown]
# sklearn.linear_model 모듈에서 LogisticRegression 함수를 불러오고, sklearn.metrics에서 log_loss 와 roc_auc_scire 함수를 불러옵니다.
#
# log_loss는 로지스틱 회귀를 학습/평가할 때 사용하는 손실함수이며, roc_auc_score는 분류 모델의 성능을 측정할 때 사용하는 대표적인 지표입니다.

# %%
print(p[1, :])
# Out:
# [3.41133649e-002 6.22872890e-001 4.86041591e-002 2.11906957e-002
#  1.18063148e-001 1.39162103e-002 1.11409102e-002 1.05188198e-080
#  3.93084469e-003 1.31841072e-044 4.85016645e-002 4.76422718e-002
#  6.63695899e-005 7.30909150e-003 1.24221870e-002 2.35481248e-110
#  2.31913821e-003 3.57889362e-003 4.32816114e-003]

# %%
lr.coef_, lr.intercept_
# Out:
# (array([[ 3.49373670e-02,  2.20207043e-01,  4.02016970e-02,
#           1.46035008e-01,  2.31074753e-01,  5.87249082e-02,
#          -4.74692838e-03,  5.16729080e-04,  9.45536825e-02,
#          -2.82744204e-02, -2.49066945e-02,  3.65108785e-02,
#           6.00037400e-02,  1.60685532e-03, -3.45371666e-02,
#          -1.53209526e-02,  4.78935182e-02,  1.29266217e-02,
#          -4.46073647e-02, -7.21831958e-03, -1.31437538e-02],
#         [-2.78680570e-01,  7.14357241e-03, -1.97302725e-02,
#           3.59656031e-03, -7.80700603e-03,  8.26368239e-03,
#          -1.23683057e-02, -1.28948897e-03, -3.34449092e-02,
#          -1.34368852e-02,  5.95492164e-04,  6.64101196e-03,
#           2.42931558e-02, -1.23811636e-02, -5.67632641e-03,
#           2.43243181e-03,  5.19215761e-03,  9.55806393e-03,
#          -2.54280491e-02,  1.46203723e-02,  7.56936377e-03],
#         [ 3.36905292e-02,  1.68309796e-01,  8.89350854e-02,
#          -4.15112660e-02, -1.25607708e-01, -1.55783879e-01,
#           1.83164455e-01,  9.51170611e-04,  4.20311728e-02,
#          -6.45588683e-03, -1.54653108e-01, -8.78329962e-03,
#           8.05080650e-02,  1.46777823e-02, -6.72016916e-02,
#          -1.57709741e-01,  1.48876508e-01,  5.50224294e-02,
#           1.53330852e-01, -2.14835231e-01, -5.89185334e-02],
#         [ 3.57245407e-02,  1.91927178e-02, -1.07838796e-02,
#          -1.87536691e-03, -2.06792613e-02, -8.83487298e-03,
#          -6.91650424e-03, -2.95889341e-04, -2.42438974e-02,
#          -1.23534185e-02, -1.05825907e-02,  2.47872102e-02,
#           1.64159278e-02, -1.84160912e-02,  2.49344966e-03,
#          -1.63130175e-02,  5.08741251e-03,  8.17202208e-03,
#          -2.48577292e-02, -1.88626625e-03, -7.45402407e-03],
#         [ 3.40139081e-02, -1.06578436e-02,  4.56022475e-03,
#           3.92603211e-04, -1.56000497e-02,  2.02415398e-02,
#          -8.62652880e-03, -3.72858536e-03, -4.48397634e-02,
#           5.93184044e-03, -5.07720301e-03,  2.44882271e-02,
#           7.14149516e-03, -2.68184905e-02,  1.26950885e-02,
#           1.46451989e-02, -2.77675940e-02,  2.43143919e-02,
#          -1.54234400e-02,  3.82572652e-03,  2.85023452e-02]]),
#  array([ 0.01603356, -0.01899066,  0.0090365 ,  0.00050076,  0.00709877,
#         -0.00193373, -0.00271201, -0.003054  , -0.00367308, -0.00313477,
#          0.01272235,  0.01194693, -0.00339359, -0.00362041, -0.00102102,
#         -0.00348592, -0.00384359, -0.00409306, -0.00438301]))

# %%
log_loss(y,p)
# Out:
# 1.821238576593883

# %%
score = roc_auc_score(y,p, multi_class= 'ovr')

print(f"AUC score : {score:.4f}")
# Out:
# AUC score : 0.6944

# %%
from kaggler.metrics import plot_roc_curve, plot_pr_curve
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 from kaggler.metrics import plot_roc_curve, plot_pr_curve
#
# ModuleNotFoundError: No module named 'kaggler'

# %%
plt.figure(figsize=(16, 16))
plt.subplot(1, 2, 1)
plot_roc_curve(y, p);
plt.title('AUC Curve')
plt.subplot(1, 2, 2)
plot_pr_curve(y, p);
plt.title('Precision-Recall Curve')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[88], line 3
#       1 plt.figure(figsize=(16, 16))
#       2 plt.subplot(1, 2, 1)
# ----> 3 plot_roc_curve(y, p);
#       4 plt.title('AUC Curve')
#       5 plt.subplot(1, 2, 2)
#
# NameError: name 'plot_roc_curve' is not defined
